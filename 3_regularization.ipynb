# %% [markdown]
# Deep Learning
# =============
#
# Assignment 3
# ------------
#
# Previously in `2_fullyconnected.ipynb`, you trained a logistic regression and a neural network model.
#
# The goal of this assignment is to explore regularization techniques.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle

# %% [markdown]
# First reload the data we generated in `1_notmnist.ipynb`.

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a shape that's more adapted to the models we're going to train:
# - data as a flat matrix,
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10

def reformat(dataset, labels):
  dataset = dataset.reshape((-1, image_size * image_size)).astype(np.float32)
  # Map 1 to [0.0, 1.0, 0.0 ...], 2 to [0.0, 0.0, 1.0 ...]
  #print(labels[:,None])
  #Convert to 1 hot
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 784) (200000, 10)
# Validation set (10000, 784) (10000, 10)
# Test set (10000, 784) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# ---
# Problem 1
# ---------
#
# Introduce and tune L2 regularization for both logistic and neural network models. Remember that L2 amounts to adding a penalty on the norm of the weights to the loss. In TensorFlow, you can compute the L2 loss for a tensor `t` using `nn.l2_loss(t)`. The right amount of regularization should improve your validation / test accuracy.
#
# ---

# %%
#Logistic Regression

batch_size = 128

graph = tf.Graph()
with graph.as_default():

  # Input data. For the training data, we use a placeholder that will be fed
  # at run time with a training minibatch.
  #ANKITNOTE: There are variable for weights, constant for input data and placeholder for generators of input data
  tf_train_dataset = tf.placeholder(tf.float32,
                                    shape=(batch_size, image_size * image_size))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  print(tf_train_labels)
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  beta_regul = tf.placeholder(tf.float32)
  # Variables.
  #AnkitNOTE - Weights are normalized using truncated normal distributions
  #Normalized distribution is used to avoid "dead neurons" to void shooting on extremes of the sigmoid distribution
  weights = tf.Variable(
    tf.truncated_normal([image_size * image_size, num_labels]))
  biases = tf.Variable(tf.zeros([num_labels]))
  
  # Training computation.
  logits = tf.matmul(tf_train_dataset, weights) + biases
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits)) + 1e-3 * tf.nn.l2_loss(weights)
  
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.5).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(
    tf.matmul(tf_valid_dataset, weights) + biases)
  test_prediction = tf.nn.softmax(tf.matmul(tf_test_dataset, weights) + biases)
# Out:
# Tensor("Placeholder_1:0", shape=(128, 10), dtype=float32)
# WARNING:tensorflow:From <ipython-input-5-ef9a6653865f>:28: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %%
num_steps = 3001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print("Initialized")
  for step in range(num_steps):
    # Pick an offset within the training data, which has been randomized.
    # Note: we could use better randomization across epochs.
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    # Generate a minibatch.
    batch_data = train_dataset[offset:(offset + batch_size), :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    batch_labels1 = batch_labels.reshape(128,10)
    # Prepare a dictionary telling the session where to feed the minibatch.
    # The key of the dictionary is the placeholder node of the graph to be fed,
    # and the value is the numpy array to feed to it.
    #print(batch_labels1)
    #print(batch_data.shape)
    #print(batch_labels.shape)
    #print(batch_labels1.shape)
    
    #learn_rate = np.repeat(1e-3,128).reshape(128,10)
    #learn_rate_tf = tf.convert_to_tensor(learn_rate[:,None],np.float32)
    #print(learn_rate.shape)
    
    
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels1}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 500 == 0):
      print("Minibatch loss at step %d: %f" % (step, l))
      print("Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels))
      print("Validation accuracy: %.1f%%" % accuracy(
        valid_prediction.eval(), valid_labels))
  print("Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 17.350000
# Minibatch accuracy: 20.3%
# Validation accuracy: 17.4%
# Minibatch loss at step 500: 2.373712
# Minibatch accuracy: 79.7%
# Validation accuracy: 76.4%
# Minibatch loss at step 1000: 1.700951
# Minibatch accuracy: 78.9%
# Validation accuracy: 78.7%
# Minibatch loss at step 1500: 1.058264
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.7%
# Minibatch loss at step 2000: 1.048929
# Minibatch accuracy: 78.9%
# Validation accuracy: 81.5%
# Minibatch loss at step 2500: 0.860573
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.8%
# Minibatch loss at step 3000: 0.884466
# Minibatch accuracy: 77.3%
# Validation accuracy: 82.4%
# Test accuracy: 88.7%

# %% [markdown]
# ---
# Problem 2
# ---------
# Let's demonstrate an extreme case of overfitting. Restrict your training data to just a few batches. What happens?
#
# ---

# %%
batch_size = 128
num_hidden_nodes = 1024

graph = tf.Graph()
with graph.as_default():

  # Input data. For the training data, we use a placeholder that will be fed
  # at run time with a training minibatch.
  tf_train_dataset = tf.placeholder(tf.float32,
                                    shape=(batch_size, image_size * image_size))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  beta_regul = tf.placeholder(tf.float32)
  
  # Variables.
  weights1 = tf.Variable(
    tf.truncated_normal([image_size * image_size, num_hidden_nodes]))
  biases1 = tf.Variable(tf.zeros([num_hidden_nodes]))
  weights2 = tf.Variable(
    tf.truncated_normal([num_hidden_nodes, num_labels]))
  biases2 = tf.Variable(tf.zeros([num_labels]))
  
  # Training computation.
  lay1_train = tf.nn.relu(tf.matmul(tf_train_dataset, weights1) + biases1)
  logits = tf.matmul(lay1_train, weights2) + biases2
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=tf_train_labels))
  
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.5).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  lay1_valid = tf.nn.relu(tf.matmul(tf_valid_dataset, weights1) + biases1)
  valid_prediction = tf.nn.softmax(tf.matmul(lay1_valid, weights2) + biases2)
  lay1_test = tf.nn.relu(tf.matmul(tf_test_dataset, weights1) + biases1)
  test_prediction = tf.nn.softmax(tf.matmul(lay1_test, weights2) + biases2)

# %%
num_steps = 101
num_batches = 3

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print("Initialized")
  for step in range(num_steps):
    # Pick an offset within the training data, which has been randomized.
    # Note: we could use better randomization across epochs.
    #offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    offset = ((step % num_batches) * batch_size) % (train_labels.shape[0] - batch_size)
    # Generate a minibatch.
    batch_data = train_dataset[offset:(offset + batch_size), :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    # Prepare a dictionary telling the session where to feed the minibatch.
    # The key of the dictionary is the placeholder node of the graph to be fed,
    # and the value is the numpy array to feed to it.
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels, beta_regul : 1e-3}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 2 == 0):
      print("Minibatch loss at step %d: %f" % (step, l))
      print("Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels))
      print("Validation accuracy: %.1f%%" % accuracy(
        valid_prediction.eval(), valid_labels))
  print("Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels))
# Out:
# WARNING:tensorflow:From /home/Ankit/anaconda3/envs/fastai/lib/python3.6/site-packages/tensorflow/python/util/tf_should_use.py:189: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Minibatch loss at step 0: 327.952423
# Minibatch accuracy: 19.5%
# Validation accuracy: 37.1%
# Minibatch loss at step 2: 706.216309
# Minibatch accuracy: 38.3%
# Validation accuracy: 45.6%
# Minibatch loss at step 4: 355.436981
# Minibatch accuracy: 55.5%
# Validation accuracy: 55.2%
# Minibatch loss at step 6: 112.658287
# Minibatch accuracy: 68.0%
# Validation accuracy: 63.7%
# Minibatch loss at step 8: 53.331100
# Minibatch accuracy: 82.0%
# Validation accuracy: 72.4%
# Minibatch loss at step 10: 5.276173
# Minibatch accuracy: 93.0%
# Validation accuracy: 74.1%
# Minibatch loss at step 12: 5.649225
# Minibatch accuracy: 96.1%
# Validation accuracy: 73.5%
# Minibatch loss at step 14: 0.046171
# Minibatch accuracy: 99.2%
# Validation accuracy: 73.7%
# Minibatch loss at step 16: 0.336543
# Minibatch accuracy: 99.2%
# Validation accuracy: 74.0%
# Minibatch loss at step 18: 0.000018
# Minibatch accuracy: 100.0%
# Validation accuracy: 74.0%
# Minibatch loss at step 20: 0.000010
# Minibatch accuracy: 100.0%
# Validation accuracy: 74.0%
# Minibatch loss at step 22: 0.000001
# Minibatch accuracy: 100.0%
# Validation accuracy: 74.0%
# Minibatch loss at step 24: 0.000007
# Minibatch accuracy: 100.0%
# Validation accuracy: 74.0%
# Minibatch loss at step 26: 0.000008
# Minibatch accuracy: 100.0%
# Validation accuracy: 74.0%
# Minibatch loss at step 28: 0.000001
# Minibatch accuracy: 100.0%
# Validation accuracy: 74.0%
# Minibatch loss at step 30: 0.000005
# Minibatch accuracy: 100.0%
# Validation accuracy: 74.0%
# Minibatch loss at step 32: 0.000008
# Minibatch accuracy: 100.0%
# Validation accuracy: 74.0%
# Minibatch loss at step 34: 0.000001
# Minibatch accuracy: 100.0%
# Validation accuracy: 74.0%
# Minibatch loss at step 36: 0.000004
# Minibatch accuracy: 100.0%
# Validation accuracy: 74.0%
# Minibatch loss at step 38: 0.000007
# Minibatch accuracy: 100.0%
# Validation accuracy: 74.0%
# Minibatch loss at step 40: 0.000001
# Minibatch accuracy: 100.0%
# Validation accuracy: 74.0%
# Minibatch loss at step 42: 0.000003
# Minibatch accuracy: 100.0%
# Validation accuracy: 74.0%
# Minibatch loss at step 44: 0.000006
# Minibatch accuracy: 100.0%
# Validation accuracy: 74.0%
# Minibatch loss at step 46: 0.000001
# Minibatch accuracy: 100.0%
# Validation accuracy: 74.0%
# Minibatch loss at step 48: 0.000002
# Minibatch accuracy: 100.0%
# Validation accuracy: 74.0%
# Minibatch loss at step 50: 0.000006
# Minibatch accuracy: 100.0%
# Validation accuracy: 74.0%
# Minibatch loss at step 52: 0.000001
# Minibatch accuracy: 100.0%
# Validation accuracy: 74.0%
# Minibatch loss at step 54: 0.000002
# Minibatch accuracy: 100.0%
# Validation accuracy: 74.0%
# Minibatch loss at step 56: 0.000005
# Minibatch accuracy: 100.0%
# Validation accuracy: 74.0%
# Minibatch loss at step 58: 0.000001
# Minibatch accuracy: 100.0%
# Validation accuracy: 74.0%
# Minibatch loss at step 60: 0.000002
# Minibatch accuracy: 100.0%
# Validation accuracy: 74.0%
# Minibatch loss at step 62: 0.000005
# Minibatch accuracy: 100.0%
# Validation accuracy: 74.0%
# Minibatch loss at step 64: 0.000001
# Minibatch accuracy: 100.0%
# Validation accuracy: 74.0%
# Minibatch loss at step 66: 0.000002
# Minibatch accuracy: 100.0%
# Validation accuracy: 74.0%
# Minibatch loss at step 68: 0.000005
# Minibatch accuracy: 100.0%
# Validation accuracy: 74.0%
# Minibatch loss at step 70: 0.000001
# Minibatch accuracy: 100.0%
# Validation accuracy: 74.0%
# Minibatch loss at step 72: 0.000001
# Minibatch accuracy: 100.0%
# Validation accuracy: 74.0%
# Minibatch loss at step 74: 0.000004
# Minibatch accuracy: 100.0%
# Validation accuracy: 74.0%
# Minibatch loss at step 76: 0.000001
# Minibatch accuracy: 100.0%
# Validation accuracy: 74.0%
# Minibatch loss at step 78: 0.000001
# Minibatch accuracy: 100.0%
# Validation accuracy: 74.0%
# Minibatch loss at step 80: 0.000004
# Minibatch accuracy: 100.0%
# Validation accuracy: 74.0%
# Minibatch loss at step 82: 0.000001
# Minibatch accuracy: 100.0%
# Validation accuracy: 74.0%
# Minibatch loss at step 84: 0.000001
# Minibatch accuracy: 100.0%
# Validation accuracy: 74.0%
# Minibatch loss at step 86: 0.000004
# Minibatch accuracy: 100.0%
# Validation accuracy: 74.0%
# Minibatch loss at step 88: 0.000001
# Minibatch accuracy: 100.0%
# Validation accuracy: 74.0%
# Minibatch loss at step 90: 0.000001
# Minibatch accuracy: 100.0%
# Validation accuracy: 74.0%
# Minibatch loss at step 92: 0.000004
# Minibatch accuracy: 100.0%
# Validation accuracy: 74.0%
# Minibatch loss at step 94: 0.000001
# Minibatch accuracy: 100.0%
# Validation accuracy: 74.0%
# Minibatch loss at step 96: 0.000001
# Minibatch accuracy: 100.0%
# Validation accuracy: 74.0%
# Minibatch loss at step 98: 0.000004
# Minibatch accuracy: 100.0%
# Validation accuracy: 74.0%
# Minibatch loss at step 100: 0.000001
# Minibatch accuracy: 100.0%
# Validation accuracy: 74.0%
# Test accuracy: 79.9%

# %% [raw]
# Since there are only 3 batches exposed to the network, it starts memorizing and gives a high mini-batch accuracy. However, the validation and test accuracy is poor. This causes overfitting - a few neurons tend to acquire higher weights and bais the network towards judgement based off memorization rather than generalization.

# %% [markdown]
# ---
# Problem 3
# ---------
# Introduce Dropout on the hidden layer of the neural network. Remember: Dropout should only be introduced during training, not evaluation, otherwise your evaluation results would be stochastic as well. TensorFlow provides `nn.dropout()` for that, but you have to make sure it's only inserted during training.
#
# What happens to our extreme overfitting case?
#
# ---

# %%
batch_size = 128
num_hidden_nodes = 1024

graph = tf.Graph()
with graph.as_default():

  # Input data. For the training data, we use a placeholder that will be fed
  # at run time with a training minibatch.
  tf_train_dataset = tf.placeholder(tf.float32,
                                    shape=(batch_size, image_size * image_size))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  weights1 = tf.Variable(
    tf.truncated_normal([image_size * image_size, num_hidden_nodes]))
  biases1 = tf.Variable(tf.zeros([num_hidden_nodes]))
  weights2 = tf.Variable(
    tf.truncated_normal([num_hidden_nodes, num_labels]))
  biases2 = tf.Variable(tf.zeros([num_labels]))
  
  # Training computation.
  lay1_train = tf.nn.relu(tf.matmul(tf_train_dataset, weights1) + biases1)
  drop1 = tf.nn.dropout(lay1_train, 0.5)
  logits = tf.matmul(drop1, weights2) + biases2
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.5).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  lay1_valid = tf.nn.relu(tf.matmul(tf_valid_dataset, weights1) + biases1)
  valid_prediction = tf.nn.softmax(tf.matmul(lay1_valid, weights2) + biases2)
  lay1_test = tf.nn.relu(tf.matmul(tf_test_dataset, weights1) + biases1)
  test_prediction = tf.nn.softmax(tf.matmul(lay1_test, weights2) + biases2)

# %%
num_steps = 101
num_batches = 3

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print("Initialized")
  for step in range(num_steps):
    # Pick an offset within the training data, which has been randomized.
    # Note: we could use better randomization across epochs.
    #offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    offset = ((step % num_batches) * batch_size) % (train_labels.shape[0] - batch_size)
    # Generate a minibatch.
    batch_data = train_dataset[offset:(offset + batch_size), :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    # Prepare a dictionary telling the session where to feed the minibatch.
    # The key of the dictionary is the placeholder node of the graph to be fed,
    # and the value is the numpy array to feed to it.
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 2 == 0):
      print("Minibatch loss at step %d: %f" % (step, l))
      print("Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels))
      print("Validation accuracy: %.1f%%" % accuracy(
        valid_prediction.eval(), valid_labels))
  print("Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 479.666504
# Minibatch accuracy: 9.4%
# Validation accuracy: 33.1%
# Minibatch loss at step 2: 959.478821
# Minibatch accuracy: 48.4%
# Validation accuracy: 40.2%
# Minibatch loss at step 4: 370.571930
# Minibatch accuracy: 49.2%
# Validation accuracy: 58.1%
# Minibatch loss at step 6: 114.411934
# Minibatch accuracy: 75.0%
# Validation accuracy: 71.6%
# Minibatch loss at step 8: 59.040684
# Minibatch accuracy: 79.7%
# Validation accuracy: 75.3%
# Minibatch loss at step 10: 25.925718
# Minibatch accuracy: 86.7%
# Validation accuracy: 73.1%
# Minibatch loss at step 12: 21.351192
# Minibatch accuracy: 92.2%
# Validation accuracy: 73.8%
# Minibatch loss at step 14: 13.436211
# Minibatch accuracy: 93.0%
# Validation accuracy: 75.3%
# Minibatch loss at step 16: 5.530288
# Minibatch accuracy: 93.8%
# Validation accuracy: 76.3%
# Minibatch loss at step 18: 7.767434
# Minibatch accuracy: 93.8%
# Validation accuracy: 75.2%
# Minibatch loss at step 20: 4.800401
# Minibatch accuracy: 93.8%
# Validation accuracy: 74.0%
# Minibatch loss at step 22: 10.741312
# Minibatch accuracy: 93.0%
# Validation accuracy: 75.8%
# Minibatch loss at step 24: 3.993247
# Minibatch accuracy: 96.1%
# Validation accuracy: 74.6%
# Minibatch loss at step 26: 11.233353
# Minibatch accuracy: 92.2%
# Validation accuracy: 75.5%
# Minibatch loss at step 28: 1.508901
# Minibatch accuracy: 96.1%
# Validation accuracy: 77.2%
# Minibatch loss at step 30: 6.636765
# Minibatch accuracy: 94.5%
# Validation accuracy: 75.3%
# Minibatch loss at step 32: 6.767623
# Minibatch accuracy: 95.3%
# Validation accuracy: 76.9%
# Minibatch loss at step 34: 2.865098
# Minibatch accuracy: 96.9%
# Validation accuracy: 76.2%
# Minibatch loss at step 36: 7.657495
# Minibatch accuracy: 96.1%
# Validation accuracy: 76.2%
# Minibatch loss at step 38: 7.592836
# Minibatch accuracy: 94.5%
# Validation accuracy: 76.8%
# Minibatch loss at step 40: 5.371456
# Minibatch accuracy: 96.9%
# Validation accuracy: 76.8%
# Minibatch loss at step 42: 0.626018
# Minibatch accuracy: 98.4%
# Validation accuracy: 77.7%
# Minibatch loss at step 44: 4.667285
# Minibatch accuracy: 95.3%
# Validation accuracy: 76.2%
# Minibatch loss at step 46: 6.232706
# Minibatch accuracy: 96.1%
# Validation accuracy: 76.9%
# Minibatch loss at step 48: 0.896835
# Minibatch accuracy: 98.4%
# Validation accuracy: 76.6%
# Minibatch loss at step 50: 1.963058
# Minibatch accuracy: 95.3%
# Validation accuracy: 76.6%
# Minibatch loss at step 52: 5.074695
# Minibatch accuracy: 97.7%
# Validation accuracy: 76.6%
# Minibatch loss at step 54: 2.108246
# Minibatch accuracy: 98.4%
# Validation accuracy: 77.2%
# Minibatch loss at step 56: 1.417949
# Minibatch accuracy: 96.1%
# Validation accuracy: 76.5%
# Minibatch loss at step 58: 0.068284
# Minibatch accuracy: 99.2%
# Validation accuracy: 76.5%
# Minibatch loss at step 60: 0.768617
# Minibatch accuracy: 98.4%
# Validation accuracy: 77.1%
# Minibatch loss at step 62: 0.201286
# Minibatch accuracy: 97.7%
# Validation accuracy: 77.2%
# Minibatch loss at step 64: 1.320501
# Minibatch accuracy: 96.1%
# Validation accuracy: 76.6%
# Minibatch loss at step 66: 1.541769
# Minibatch accuracy: 98.4%
# Validation accuracy: 76.4%
# Minibatch loss at step 68: 0.444679
# Minibatch accuracy: 99.2%
# Validation accuracy: 76.4%
# Minibatch loss at step 70: 0.443327
# Minibatch accuracy: 98.4%
# Validation accuracy: 76.3%
# Minibatch loss at step 72: 0.000000
# Minibatch accuracy: 100.0%
# Validation accuracy: 76.3%
# Minibatch loss at step 74: 1.077691
# Minibatch accuracy: 98.4%
# Validation accuracy: 76.4%
# Minibatch loss at step 76: 1.103204
# Minibatch accuracy: 98.4%
# Validation accuracy: 76.4%
# Minibatch loss at step 78: 0.000000
# Minibatch accuracy: 100.0%
# Validation accuracy: 76.4%
# Minibatch loss at step 80: 1.046085
# Minibatch accuracy: 98.4%
# Validation accuracy: 77.5%
# Minibatch loss at step 82: 1.715089
# Minibatch accuracy: 98.4%
# Validation accuracy: 76.2%
# Minibatch loss at step 84: 0.000002
# Minibatch accuracy: 100.0%
# Validation accuracy: 77.3%
# Minibatch loss at step 86: 2.055114
# Minibatch accuracy: 98.4%
# Validation accuracy: 76.6%
# Minibatch loss at step 88: 1.552076
# Minibatch accuracy: 98.4%
# Validation accuracy: 76.4%
# Minibatch loss at step 90: 0.000000
# Minibatch accuracy: 100.0%
# Validation accuracy: 76.4%
# Minibatch loss at step 92: 0.747300
# Minibatch accuracy: 99.2%
# Validation accuracy: 76.9%
# Minibatch loss at step 94: 1.872525
# Minibatch accuracy: 97.7%
# Validation accuracy: 77.0%
# Minibatch loss at step 96: 0.000000
# Minibatch accuracy: 100.0%
# Validation accuracy: 77.0%
# Minibatch loss at step 98: 0.415495
# Minibatch accuracy: 97.7%
# Validation accuracy: 76.7%
# Minibatch loss at step 100: 0.852893
# Minibatch accuracy: 97.7%
# Validation accuracy: 76.5%
# Test accuracy: 82.7%

# %% [raw]
# The network generalizes better with Dropout Regularization. Observations are the mini-batch accuracy of 100% is not true for every case. Also, the validation accuracy increases.

# %% [markdown]
# ---
# Problem 4
# ---------
#
# Try to get the best performance you can using a multi-layer model! The best reported test accuracy using a deep network is [97.1%](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html?showComment=1391023266211#c8758720086795711595).
#
# One avenue you can explore is to add multiple layers.
#
# Another one is to use learning rate decay:
#
#     global_step = tf.Variable(0)  # count the number of steps taken.
#     learning_rate = tf.train.exponential_decay(0.5, global_step, ...)
#     optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)
#
#  ---
#
# Let's try to add layers and use drop out regularlization

# %%
batch_size = 128
num_hidden_nodes1 = 1024
num_hidden_nodes2 = 512
num_hidden_nodes3 = 256
keep_prob = 0.5

graph = tf.Graph()
with graph.as_default():

  # Input data. For the training data, we use a placeholder that will be fed
  # at run time with a training minibatch.
  tf_train_dataset = tf.placeholder(tf.float32,
                                    shape=(batch_size, image_size * image_size))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  global_step = tf.Variable(0)

  # Variables.
  weights1 = tf.Variable(
    tf.truncated_normal(
        [image_size * image_size, num_hidden_nodes1],
        stddev=np.sqrt(2.0 / (image_size * image_size)))
    )
  biases1 = tf.Variable(tf.zeros([num_hidden_nodes1]))
  weights2 = tf.Variable(
    tf.truncated_normal([num_hidden_nodes1, num_hidden_nodes2], stddev=np.sqrt(2.0 / num_hidden_nodes1)))
  biases2 = tf.Variable(tf.zeros([num_hidden_nodes2]))
  weights3 = tf.Variable(
    tf.truncated_normal([num_hidden_nodes2, num_hidden_nodes3], stddev=np.sqrt(2.0 / num_hidden_nodes2)))
  biases3 = tf.Variable(tf.zeros([num_hidden_nodes3]))
  weights4 = tf.Variable(
    tf.truncated_normal([num_hidden_nodes3, num_labels], stddev=np.sqrt(2.0 / num_hidden_nodes3)))
  biases4 = tf.Variable(tf.zeros([num_labels]))
  
  # Training computation.
  lay1_train = tf.nn.relu(tf.matmul(tf_train_dataset, weights1) + biases1)
  drop1 = tf.nn.dropout(lay1_train, 0.5)
  lay2_train = tf.nn.relu(tf.matmul(drop1, weights2) + biases2)
  drop2 = tf.nn.dropout(lay2_train, 0.5)
  lay3_train = tf.nn.relu(tf.matmul(drop2, weights3) + biases3)
  drop3 = tf.nn.dropout(lay3_train, 0.5)
  logits = tf.matmul(drop3, weights4) + biases4
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=tf_train_labels))
    
  # Optimizer.
  learning_rate = tf.train.exponential_decay(0.5, global_step, 5000, 0.80, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  lay1_valid = tf.nn.relu(tf.matmul(tf_valid_dataset, weights1) + biases1)
  lay2_valid = tf.nn.relu(tf.matmul(lay1_valid, weights2) + biases2)
  lay3_valid = tf.nn.relu(tf.matmul(lay2_valid, weights3) + biases3)
  valid_prediction = tf.nn.softmax(tf.matmul(lay3_valid, weights4) + biases4)
  lay1_test = tf.nn.relu(tf.matmul(tf_test_dataset, weights1) + biases1)
  lay2_test = tf.nn.relu(tf.matmul(lay1_test, weights2) + biases2)
  lay3_test = tf.nn.relu(tf.matmul(lay2_test, weights3) + biases3)
  test_prediction = tf.nn.softmax(tf.matmul(lay3_test, weights4) + biases4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b37cc15f4d4b> in <module>
#       5 keep_prob = 0.5
#       6
# ----> 7 graph = tf.Graph()
#       8 with graph.as_default():
#       9
#
# NameError: name 'tf' is not defined

# %%
num_steps = 10001
loss_list = []
with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print("Initialized")
  for step in range(num_steps):
    # Pick an offset within the training data, which has been randomized.
    # Note: we could use better randomization across epochs.
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    # Generate a minibatch.
    batch_data = train_dataset[offset:(offset + batch_size), :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    # Prepare a dictionary telling the session where to feed the minibatch.
    # The key of the dictionary is the placeholder node of the graph to be fed,
    # and the value is the numpy array to feed to it.
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 500 == 0):
      print("Minibatch loss at step %d: %f" % (step, l))
      print("Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels))
      print("Validation accuracy: %.1f%%" % accuracy(
        valid_prediction.eval(), valid_labels))
    a=tf.Print(loss,[loss])
      #loss_list.append(loss.eval())
  print("Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-686f817391da> in <module>
#       1 num_steps = 10001
#       2 loss_list = []
# ----> 3 with tf.Session(graph=graph) as session:
#       4   tf.initialize_all_variables().run()
#       5   print("Initialized")
#
# NameError: name 'tf' is not defined
